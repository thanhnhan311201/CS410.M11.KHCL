# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root = '/content/drive/MyDrive/Hoc_Tap/CS410_MangNeural/Final_Project'

# %% [markdown]
# # Tổng quan:
# - Ở trong bài này nhóm chúng tôi sẽ áp dụng thuật toán Genetic Algorithm để tối ưu hóa đơn mục tiêu.
# - Mục tiêu mà nhóm chúng tôi đã chọn để tối ưu hóa là ***test-accuracy*** trên 3 tập dữ liệu **cifar10-valid**, **cifar100**, **ImageNet16-200** tại **200** training epochs, giá trị của mục tiêu được đánh giá bằng hàm benchmark NAS-Bench-201.
# - Mục tiêu trong bài này là nhóm chúng tôi sẽ phát sinh ra các kiến trúc ngẫu nhiên, sau đó áp dụng thuật toán GA để tối đa hóa ***test-accuracy*** nhằm tìm ra kiến trúc có độ chính xác trên tập dữ liệu test cao nhất trong NAS-Bench-201.
# - Đồng thời nhóm cũng đã chạy thí nghiệm trên 31 random seed khác nhau nhằm tìm kích thước quần thể nhỏ nhất cần thiết (minimally required population sice - MRPS) để thuật toán GA có thể tìm ra kiến trúc tốt nhất trong NAS-Bench-201.
# - Kết quả thực nghiệm trả về kích thước quần thể nhỏ nhất cần thiết (MRPS) là **320**. Với số lượng cá thể là 320, thuật toán GA đã tìm được kiến trúc tốt nhất với ***test-accuracy*** là 91.52, đồng thời đây cũng kiến trúc tốt nhất mà nhóm đã vét cạn trong NAS-Bench-201.

# %% [markdown]
# # Khai báo thư viện

# %%
import numpy as np
import json

# %% [markdown]
# # NAS_Benchmark_201

# %% [markdown]
# ## Setup

# %% [markdown]
# 1. Tải dữ liệu của NAS-Bench-201 tại link:
#   *   [NATS-tss-v1_0-3ffb9-simple](https://drive.google.com/drive/folders/1FDXJ-nhBFHfm7pcA-wFnsBrmSFwTmK2h?usp=sharing)
# 2. Cài đặt các thư viện cần thiết:
#   *   nats_bench (pip install nats_bench)

# %%
# !pip install nats_bench
# Out:
# Collecting nats_bench
#   Downloading nats_bench-1.5-py3-none-any.whl (31 kB)
# Requirement already satisfied: numpy<=1.19.5,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from nats_bench) (1.19.5)
# Installing collected packages: nats-bench
# Successfully installed nats-bench-1.5

# %% [markdown]
# ## Khai báo thư viện

# %%
from nats_bench import create

# %% [markdown]
# ## Khởi tạo API
# * from nats_bench import create
# * api = create('path_data', 'tss', fast_mode=True)

# %%
api = create(f'{root}/NAS_Benchmark/datasets/NATS-tss-v1_0-3ffb9-simple', 'tss', fast_mode=True)
api.verbose = False
# Out:
# [2021-12-31 01:04:10] Try to create the NATS-Bench (topology) api from /content/drive/MyDrive/Hoc_Tap/CS410_MangNeural/Final_Project/NAS_Benchmark/datasets/NATS-tss-v1_0-3ffb9-simple with fast_mode=True
# [2021-12-31 01:06:02] Create NATS-Bench (topology) done with 0/15625 architectures avaliable.

# %% [markdown]
# ## Mã hóa kiến trúc
# -------------------------------------------------------------------------------
# * Các kiến trúc được biểu diễn theo định dạng:
#
#   '|operation\~0|+|operation\~0|operation\~1|+|operation\~0|operation\~1|operation~2|'
#
#   với operation có thể là 1 trong 5 loại:
#     * 'none'
#     * 'skip_connect'
#     * 'nor_conv_1x1'
#     * 'nor_conv_3x3'
#     * 'avg_pool_3x3'
#
# * Example:
#   * arch = '|none\~0|+|skip_connect\~0|none\~1|+|nor_conv_3x3\~0|nor_conv_1x1\~1|avg_pool_3x3\~2|'

# %%
def encode_arch(pop):
  arch_lst = []
  operation_matrix = ['none', 'skip_connect', 'nor_conv_1x1', 'nor_conv_3x3', 'avg_pool_3x3']
  pop = np.reshape(pop, (-1, 6))
  for arch in pop:
    arch = f'|{operation_matrix[arch[0]]}~0|+|{operation_matrix[arch[1]]}~0|{operation_matrix[arch[2]]}~1|+|{operation_matrix[arch[3]]}~0|{operation_matrix[arch[4]]}~1|{operation_matrix[arch[5]]}~2|'
    arch_lst.append(arch)

  return np.array(arch_lst)

# %% [markdown]
# ## Hàm lấy giá trị hàm mục tiêu
#
# -------------------------------------------------------------------------------
# * Tổng cộng có 15625 kiến trúc trong NAS-Bench-201. Các thông tin được truy suất bằng số thứ tự của kiến trúc đó trong dữ liệu. Do đó, chúng ta cần chuyển từ dạng biểu diễn dạng 'string' sang số thứ tự (int).
# * Syntax:
#
#   idx = api.query_index_by_arch('kiến trúc biểu diễn ở dạng string')
# * Example:
#
#   idx = api.query_index_by_arch('|none\~0|+|skip_connect\~0|none\~1|+|nor_conv_3x3\~0|nor_conv_1x1\~1|avg_pool_3x3\~2|')
# -------------------------------------------------------------------------------
# * Syntax để lấy các giá trị accuracy (training, validation, testing)
#
#   api.get_more_info(index, dataset=dataset, hp=hp)
#
#   Trong đó:
#     * index -> Vị trí của kiến trúc trong bộ benchmark (kiểu int)
#     * dataset -> Bộ dữ liệu để huấn luyện và đánh giá kiến trúc. Có thể chọn 1 trong 3 giá trị (kiểu string):
#       * 'cifar10-valid'
#       * 'cifar100'
#       * 'ImageNet16-120'
#     * hp -> Số training epochs. Có thể chọn trong 2 giá trị (kiểu string):
#       * '12'
#       * '200'
# * Kết quả trả về là 1 dictionary. Chúng ta có thể dễ dàng lấy những thông tin như mong muốn.

# %%
# def get_obj_value( arch, dataset, hp, obj_value ):   
#     idx = api.query_index_by_arch(arch)
#     info = api.get_more_info(idx, dataset=dataset, hp=str(hp), is_random=False)
#     acc_value = np.round(info[obj_value], 2)
    
#     return acc_value

# %%
def get_obj_value( arch, dataset, hp, obj_value ):
  with open(f'{root}/NAS_Benchmark/datasets/NAS_201_{dataset}_{hp}.txt', 'r') as fi:
    archs = fi.readlines()
    idx = api.query_index_by_arch(arch)
    arch_info = json.loads(archs[idx].strip())
    acc_value = arch_info[obj_value]
  
  return acc_value

# %% [markdown]
# ## Hàm lấy kiến trúc tốt nhất

# %%
def get_best_arch( dataset, hp, obj_value ):
  max_acc = 0.0

  with open(f'{root}/NAS_Benchmark/datasets/NAS_201_{dataset}_{hp}.txt', 'r') as fi:
    archs = fi.readlines()
    for arch in archs:
      arch = arch.strip()
      arch_info = json.loads(arch)
      test_accuracy = arch_info['test_accuracy']
      if test_accuracy > max_acc:
        max_acc = test_accuracy
        best_arch_index = arch_info['arch_index']
    
  return best_arch_index, max_acc

# %% [markdown]
# # Thuật toán Genetic Algorithm

# %% [markdown]
# ## Xây dựng quần thể

# %%
def initialize_population( num_individuals ):
    """
    Khởi tạo quần thể gồm num_individuals cá thể..
    
    Arguments:
    num_individuals -- Số lượng cá thể
    
    Returns:
    pop -- Ma trận (num_individuals) chứa quần thể mới được khởi tạo ngẫu nhiên.
    """
    
    ### BẮT ĐẦU CODE TỪ ĐÂY ###
    pop = np.random.randint(5, size=(num_individuals, 6))
    
    ### DỪNG CODE TẠI ĐÂY ###
    
    return pop

# %% [markdown]
# ## Đánh giá độ thích nghi của quần thể

# %%
def evaluate_population( pop, dataset, hp, obj_value ):
    """
    Hàm đánh giá tất cả cá thể trong quần thể.
    
    Arguments:
    pop -- Quàn thể cần được đánh giá.

    Returns:
    values -- Giá trị của tất cả các cá thể trong quần thể.
    """ 

    ### BẮT ĐẦU CODE TỪ ĐÂY ###
    arch_lst = encode_arch(pop)
    values = np.array([get_obj_value(ind, dataset, hp, obj_value) for ind in arch_lst])
    
    ### DỪNG CODE TẠI ĐÂY ###
    
    return values

# %% [markdown]
# ## So sánh độ thích nghi giữa hai cá thể

# %%
def better_fitness( fitness_1, fitness_2, maximization=True ):
    """
    Hàm so sánh độ thích nghi của 2 cá thể.
    
    Arguments:
    fitness_1 -- Độ thích nghi của cá thể 1.
    fitness_2 -- Độ thích nghi của cá thể 2.
    maximization -- Biến boolean cho biết bài toán đang giải thuộc dạng tối đa hoá (mặc định) hay không
    
    Returns:
    True nếu fitness_1 tốt hơn fitness_2. Ngược lại, trả về False.
    """
    
    if maximization:
        if fitness_1 > fitness_2:
            return True
    else:
        if fitness_1 < fitness_2:
            return True
        
    return False

# %% [markdown]
# ## Tourament selection

# %%
def tournament_selection( pop, pop_fitness, selection_size, tournament_size):
    """
    Hàm chọn lọc cạnh tranh.
    
    Arguments:
    pop -- Quần thể để thực hiện phép chọn lọc.
    pop_fitness -- Mảng 1 chiều chứa giá trị (độ thích nghi) của từng cá thể trong quần thể.
    selection_size -- Số lượng cá thể sẽ được chọn.
    tournament_size -- Kích thước của tournament: Số lượng các cá thể được so sánh với nhau mỗi lần.
    
    Returns:
    selected_indices -- Chỉ số của những cá thể trong quần thể pop được chọn. Chỉ số có thể được lặp lại.
    """
    
    ### BẮT ĐẦU CODE TỪ ĐÂY ### 
    num_individuals = len(pop)
    indices = np.arange(num_individuals)
    selected_indices = []
    
    while len(selected_indices) < selection_size:
        # Đảo ngẫu nhiên thứ tự các cá thể trong quần thể.
        np.random.shuffle(indices)
        
        for i in range(0, num_individuals, tournament_size):
          best_idx = i
          for idx in range(1, tournament_size):
            if better_fitness(pop_fitness[indices[i+idx]], pop_fitness[indices[best_idx]]):
              best_idx = i + idx
          selected_indices.append(indices[best_idx])
    
    selected_indices = np.array(selected_indices)        

    ### DỪNG CODE TẠI ĐÂY ###
    
    return selected_indices

# %% [markdown]
# ## Lai ghép quần thể

# %%
def variation( pop ):
    """
    Hàm biến đổi tạo ra các cá thể con.
    
    Arguments:
    pop -- Quàn thể hiện tại.

    Returns:
    offspring -- Quần thể chứa các cá thể con được sinh ra.
    """  
    
    ### BẮT ĐẦU CODE TỪ ĐÂY ### 
    num_individuals = len(pop)
    indices = np.arange(num_individuals)
    # Đảo ngẫu nhiên thứ tự các cá thể trong quần thể
    np.random.shuffle(indices)
    offspring = []
    
    for i in range(0, num_individuals, 2):
        idx1 = indices[i]
        idx2 = indices[i+1]
        offspring1 = list(pop[idx1])
        offspring2 = list(pop[idx2])
        
        # Cài đặt phép lai đồng nhất uniform crossover. 
        # Không cần cài đặt đột biến mutation.
        for idx in range(0, 6):
          r = np.random.rand()
          if r < 0.5:
            temp = offspring2[idx]
            offspring2[idx] = offspring1[idx]
            offspring1[idx] = temp

        offspring.append(offspring1)
        offspring.append(offspring2)


    ### DỪNG CODE TẠI ĐÂY ###
    
    offspring = np.array(offspring)
    return offspring

# %% [markdown]
# ## Hàm kiểm tra hội tụ của quần thể

# %%
def check_convergence(pop_fitness):
  if len(np.unique(pop_fitness)) == 1:
    return True
    
  return False

# %% [markdown]
# ## Hàm kiểm tra tối ưu của quần thể

# %%
def check_optimal(best_fitness, pop_fitness):
  if best_fitness in pop_fitness:
    return True

  return False

# %% [markdown]
# ## Thuật toán POPOP

# %%
def popop(num_individuals, dataset, hp, obj_value):
    """
    Hàm cài đặt thuật giải di truyền theo các bước P->O->(P+O)->P
    
    Arguments:
    num_individuals -- Số lượng cá thể trong quần thể.
    num_generations -- Số thế hệ thuật toán sẽ chạy.

    Returns:
    In ra quần thể ở thế hệ cuối cùng và giá trị của từng cá thể.
    """ 

    ### BẮT ĐẦU CODE TỪ ĐÂY ### 
    # Khởi tạo quần thể
    pop = initialize_population(num_individuals)
    original_pop = np.copy(pop)
    pop_fitness = evaluate_population(pop, dataset, hp, obj_value)
    original_pop_fitness = np.copy(pop_fitness)
    
    # Sử dụng tournament_size 4 và selection_size là bằng kích thước quần thể
    selection_size = len(pop)
    tournament_size = 4
    num_generations = 0

    while not check_convergence(pop_fitness):
        num_generations += 1
        # Tạo ra các cá thể con và đánh giá chúng
        offspring = variation(pop)
        offspring_fitness = evaluate_population(offspring, dataset, hp, obj_value)
        
        # Tạo ra quần thể pool gồm quần thể hiện tại pop và offspring
        pool = np.vstack((pop,offspring))
        pool_fitness = np.hstack((pop_fitness, offspring_fitness))

        # Thực hiện tournament selection trên quần thể pool 
        pool_indices = tournament_selection(pool, pool_fitness, selection_size, tournament_size)

        # Thay thế quần thể hiện tại bằng những cá thể được chọn ra từ pool.
        pop = pool[pool_indices, :]
        pop_fitness = pool_fitness[pool_indices]

    ### DỪNG CODE TẠI ĐÂY ###

    return [original_pop, original_pop_fitness, pop, pop_fitness, num_generations]

# %% [markdown]
# ## Hàm ghi chép quá trình tìm kiếm MRPS của quần thể

# %%
def record(lines):
  record_file = open(f'{root}/report/MRPS_record.txt', 'a')
  for line in lines:
    record_file.write(line)
    record_file.write('\n')
    print(line)

# %%
def MRPS_record(type_record=None, dataset=None, hp=None, obj_value=None, pop_size=None, seed=None, s_flag=None, mrps=None, upper_bound=None):
  lines = []
  
  if type_record == 1:
    line1 = '|--------------------------------MRPS RECORD--------------------------------|'
    line2 = '|-----------------------------------BEGIN-----------------------------------|\n'
    lines.append(line1)
    lines.append(line2)
    record(lines)
  elif type_record == 2:
    line = '\n|-----------------------------------DONE-----------------------------------|'
    lines.append(line)
    record(lines) 
  elif type_record == 3:
    line = f'- Algorithm = Genetic Algorithm, Objective value = {obj_value}, Dataset = {dataset}, Checkpoint = {hp}'
    lines.append(line)
    record(lines)
  elif type_record == 4:
    line = f'\t- Finding the upper bound of MRPS'
    lines.append(line)
    record(lines)
  elif type_record == 5:
    line = f'\t\t- Population size = {pop_size}'
    lines.append(line)
    record(lines)
  elif type_record == 6:
    line = f'\t\t\t{seed}-th seed'
    lines.append(line)
    record(lines)
  elif type_record == 7:
    if s_flag == True:
      line = '\t\t\t\tThe best architecture has been found!'
    else:
      line = "\t\t\t\tCan't find the best architecture!"
    lines.append(line)
    record(lines)
  elif type_record == 8:
    line = f'\n\t- Finding the MRPS'
    lines.append(line)
    record(lines)
  elif type_record == 9:
    line = f'\n\t- Minimally required population size to find the best architecture: {mrps}'
    line1 = '\tSaving...'
    line2 = '\tSaved record!\n'
    lines.append(line)
    lines.append(line1)
    lines.append(line2)
    record(lines)
  elif type_record == 10:
    line = f"\n\t- Can't find the minimally required population size to find the best architecture"
    line1 = '\tSaving...'
    line2 = '\tSaved record!\n'
    lines.append(line)
    lines.append(line1)
    lines.append(line2)
    record(lines)
  elif type_record == 11:
    line = f'\t\t The upper bound of MRPS: {upper_bound}'
    lines.append(line)
    record(lines)

# %% [markdown]
# ## Hàm đánh giá thuật toán sGA với 10 random seed khác nhau

# %%
def evaluate_sGA(num_individuals, dataset, hp, obj_value, highest_obj_value):
  MRPS_record(type_record=5, pop_size=num_individuals)
  for i in range(31):
    MRPS_record(type_record=6, seed=i)
    np.random.seed(i)
    pop_fitness = popop(num_individuals, dataset, hp, obj_value)[3]
    if not check_optimal(highest_obj_value, pop_fitness):
      MRPS_record(type_record=7, s_flag=False)
      return False
    MRPS_record(type_record=7, s_flag=True)

  return True

# %% [markdown]
# ## Hàm tìm kiếm cận trên của population size

# %%
def upper_bound(dataset, hp, obj_value, highest_obj_value, cant_solve):
  MRPS_record(type_record=4)
  upper_popSize = 4
  while not evaluate_sGA(upper_popSize, dataset, hp, obj_value, highest_obj_value):
    upper_popSize *= 2

    if upper_popSize > 15624:
      cant_solve = True
      break
  MRPS_record(type_record=11, upper_bound=upper_popSize)
  return upper_popSize, cant_solve

# %% [markdown]
# ## Hàm tìm kiếm MRPS của quần thể

# %%
def MRPS(upper_popSize, dataset, hp, obj_value, highest_obj_value):
  MRPS_record(type_record=8)
  lower_popSize = upper_popSize // 2
  while (upper_popSize - lower_popSize) / upper_popSize > 0.1:
    popSize = (upper_popSize + lower_popSize) // 2
    flag = evaluate_sGA(popSize, dataset, hp, obj_value, highest_obj_value)
    if flag:
      upper_popSize = popSize
    else:
      lower_popSize = popSize

    if (upper_popSize - lower_popSize) <= 2:
      break

  MRPS_record(type_record=9, mrps=upper_popSize)
  return upper_popSize

# %% [markdown]
# ## Bisection

# %%
def bisection(dataset, hp, obj_value, highest_obj_value):
  MRPS_record(type_record=3, dataset=dataset, hp=hp, obj_value=obj_value)
  cant_solve = False
  upper_popSize, cant_solve = upper_bound(dataset, hp, obj_value, highest_obj_value, cant_solve)

  if cant_solve:
    MRPS_record(type_record=10)
    return None

  mrps = MRPS(upper_popSize, dataset, hp, obj_value, highest_obj_value)

  return mrps

# %% [markdown]
# # Tối ưu hóa kiến trúc

# %% [markdown]
#   * dataset -> Bộ dữ liệu để huấn luyện và đánh giá kiến trúc. Có thể chọn 1 trong 3 giá trị (kiểu string):
#     * 'cifar10-valid'
#     * 'cifar100'
#     * 'ImageNet16-120'
#   * hp -> Số training epochs. Có thể chọn trong 2 giá trị (kiểu string):
#     * '12'
#     * '200'
#   * obj_value -> Giá trị hàm mục tiêu cần tối ưu
#     * 'train-accuracy'
#     * 'valid-accuracy'
#     * 'test-accuracy'

# %% [markdown]
# ## Chạy bisection tìm kích thước quần thể nhỏ nhất cần thiết để tìm kiến trúc tối ưu nhất

# %%
datasets = ['cifar10-valid', 'cifar100', 'ImageNet16-120']
hp = 200
# obj_value = 'test-accuracy'
obj_value = 'test_accuracy'

# %%
exp_results = {}
MRPS_record(type_record=1)

for dataset in datasets:
  temp = {}

  best_arch_index, highest_test_accuracy = get_best_arch(dataset, hp, obj_value)
  mrps = bisection(dataset, hp, obj_value, highest_test_accuracy)

  temp['mrps'] = mrps
  temp['best_arch'] = api.arch(best_arch_index)
  temp['highest_test_accuracy'] = highest_test_accuracy

  exp_results[dataset] = temp
MRPS_record(type_record=2)
# Out:
# |--------------------------------MRPS RECORD--------------------------------|
# |-----------------------------------BEGIN-----------------------------------|
#
# - Algorithm = Genetic Algorithm, Objective value = test_accuracy, Dataset = cifar10-valid, Checkpoint = 200
# 	- Finding the upper bound of MRPS
# 		- Population size = 4
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 8
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 16
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 32
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 64
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 128
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				Can't find the best architecture!
# 		- Population size = 256
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				Can't find the best architecture!
# 		- Population size = 512
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		 The upper bound of MRPS: 512
#
# 	- Finding the MRPS
# 		- Population size = 384
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		- Population size = 320
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		- Population size = 288
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				Can't find the best architecture!
#
# 	- Minimally required population size to find the best architecture: 320
# 	Saving...
# 	Saved record!
#
# - Algorithm = Genetic Algorithm, Objective value = test_accuracy, Dataset = cifar100, Checkpoint = 200
# 	- Finding the upper bound of MRPS
# 		- Population size = 4
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 8
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 16
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 32
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				Can't find the best architecture!
# 		- Population size = 64
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				Can't find the best architecture!
# 		- Population size = 128
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		 The upper bound of MRPS: 128
#
# 	- Finding the MRPS
# 		- Population size = 96
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		- Population size = 80
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		- Population size = 72
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				Can't find the best architecture!
#
# 	- Minimally required population size to find the best architecture: 80
# 	Saving...
# 	Saved record!
#
# - Algorithm = Genetic Algorithm, Objective value = test_accuracy, Dataset = ImageNet16-120, Checkpoint = 200
# 	- Finding the upper bound of MRPS
# 		- Population size = 4
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 8
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 16
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 32
# 			0-th seed
# 				Can't find the best architecture!
# 		- Population size = 64
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				Can't find the best architecture!
# 		- Population size = 128
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				Can't find the best architecture!
# 		- Population size = 256
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				The best architecture has been found!
# 			22-th seed
# 				The best architecture has been found!
# 			23-th seed
# 				The best architecture has been found!
# 			24-th seed
# 				The best architecture has been found!
# 			25-th seed
# 				The best architecture has been found!
# 			26-th seed
# 				The best architecture has been found!
# 			27-th seed
# 				The best architecture has been found!
# 			28-th seed
# 				The best architecture has been found!
# 			29-th seed
# 				The best architecture has been found!
# 			30-th seed
# 				The best architecture has been found!
# 		 The upper bound of MRPS: 256
#
# 	- Finding the MRPS
# 		- Population size = 192
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				Can't find the best architecture!
# 		- Population size = 224
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				Can't find the best architecture!
# 		- Population size = 240
# 			0-th seed
# 				The best architecture has been found!
# 			1-th seed
# 				The best architecture has been found!
# 			2-th seed
# 				The best architecture has been found!
# 			3-th seed
# 				The best architecture has been found!
# 			4-th seed
# 				The best architecture has been found!
# 			5-th seed
# 				The best architecture has been found!
# 			6-th seed
# 				The best architecture has been found!
# 			7-th seed
# 				The best architecture has been found!
# 			8-th seed
# 				The best architecture has been found!
# 			9-th seed
# 				The best architecture has been found!
# 			10-th seed
# 				The best architecture has been found!
# 			11-th seed
# 				The best architecture has been found!
# 			12-th seed
# 				The best architecture has been found!
# 			13-th seed
# 				The best architecture has been found!
# 			14-th seed
# 				The best architecture has been found!
# 			15-th seed
# 				The best architecture has been found!
# 			16-th seed
# 				The best architecture has been found!
# 			17-th seed
# 				The best architecture has been found!
# 			18-th seed
# 				The best architecture has been found!
# 			19-th seed
# 				The best architecture has been found!
# 			20-th seed
# 				The best architecture has been found!
# 			21-th seed
# 				Can't find the best architecture!
#
# 	- Minimally required population size to find the best architecture: 256
# 	Saving...
# 	Saved record!
#
#
# |-----------------------------------DONE-----------------------------------|

# %% [markdown]
# ## Tối ưu hóa kiến trúc dựa trên MRPS mới tìm

# %%
for dataset in datasets:
  [original_pop, original_pop_fitness, pop, pop_fitness, num_generations] = popop(exp_results[dataset]['mrps'], dataset, hp, obj_value)

  exp_results[dataset]['final_arch'] = encode_arch(pop[-1])[-1]
  exp_results[dataset]['final_test_accuracy'] = pop_fitness[-1]
  exp_results[dataset]['num_generations'] = num_generations

  print('\n\n------------------------------------------')
  print(f'Dataset: {dataset}')
  print(f"MRPS: {exp_results[dataset]['mrps']}")
  print("Original population: ", encode_arch(original_pop))
  print("Original population's fitness: ", original_pop_fitness)
  print("Final population", encode_arch(pop[-1]))
  print("Final population's fitness: ", pop_fitness)
  print("Num of generations:", num_generations)

  print(f"\nThe best architecture: {exp_results[dataset]['best_arch']}")
  print(f"The highest test accuracy: {exp_results[dataset]['highest_test_accuracy']}")

out_file = open(f"{root}/report/SOOP_results.json", "w")
json.dump(exp_results, out_file, indent = 6)
out_file.close()
# Out:
# ------------------------------------------
# Dataset: cifar10-valid
# MRPS: 320
# Original population:  ['|none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|none~2|'
#  '|none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|skip_connect~1|none~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|skip_connect~1|none~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|none~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|'
#  '|none~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|none~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|none~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|none~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|skip_connect~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|none~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|none~2|'
#  '|none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|none~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|none~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|none~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|none~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|'
#  '|none~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|none~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|none~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|none~1|none~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|']
# Original population's fitness:  [85.43 85.78 89.38 88.34 10.   86.06 88.24 80.96 85.44 88.51 89.41 73.37
#  89.81 90.23 86.67 89.23 84.46 83.06 85.54 81.34 82.61 70.83 88.96 86.81
#  86.06 82.25 89.4  88.6  68.78 62.64 84.25 86.57 91.03 84.49 89.23 87.45
#  77.47 88.52 85.69 87.05 87.6  82.22 82.24 62.64 85.8  88.56 86.   85.55
#  88.96 75.19 88.5  82.08 83.4  89.24 79.18 88.52 87.26 63.5  87.52 86.24
#  86.44 88.72 89.2  88.09 88.6  83.12 80.34 88.52 89.14 88.09 83.37 84.01
#  88.6  82.58 84.69 86.04 84.74 77.38 88.78 87.24 89.34 88.81 85.71 90.72
#  89.52 77.81 89.23 87.11 86.54 87.55 83.69 86.52 63.35 84.01 89.03 85.
#  89.54 88.19 87.62 86.   87.39 87.88 76.52 83.29 90.78 87.9  88.64 84.2
#  88.66 79.54 88.66 84.66 88.42 78.21 86.35 88.02 87.46 91.09 88.1  82.16
#  86.45 83.49 81.62 88.63 83.04 84.81 88.57 90.11 87.58 89.01 88.46 88.43
#  88.45 89.48 86.44 82.65 75.7  86.02 83.81 90.09 84.35 85.97 86.44 86.59
#  85.38 81.81 85.7  84.18 88.37 89.56 87.46 85.36 88.61 88.54 82.56 87.26
#  83.84 85.65 86.88 87.99 86.18 85.2  88.72 89.78 89.07 80.11 62.3  86.76
#  88.42 84.74 88.18 76.22 86.7  84.2  83.05 88.76 85.54 85.1  78.08 90.88
#  84.14 88.71 89.41 84.09 86.08 85.75 88.45 76.94 85.18 88.92 89.18 90.58
#  77.06 10.   87.44 86.64 87.33 10.   87.07 89.25 71.   88.2  89.5  90.44
#  84.08 86.87 85.7  89.74 89.21 87.01 89.52 87.68 10.   85.57 89.27 81.95
#  88.09 90.53 90.75 85.13 88.66 87.84 70.87 89.29 87.62 88.2  88.28 90.22
#  89.76 87.28 86.7  88.22 81.57 70.95 88.64 90.36 88.9  84.33 85.04 88.56
#  53.24 89.21 89.38 67.08 89.42 84.18 75.5  86.34 85.12 74.38 85.31 81.91
#  87.   89.76 86.96 90.27 86.64 80.18 80.55 89.29 85.38 85.61 83.01 90.26
#  87.32 87.31 78.03 86.28 88.79 88.72 87.61 88.95 89.3  90.16 91.16 90.25
#  63.05 87.11 86.6  87.3  87.93 86.31 86.1  90.22 87.26 82.84 10.   89.46
#  90.41 89.53 85.5  76.99 83.63 85.72 88.2  86.17 55.53 85.3  90.68 88.75
#  88.64 88.9  89.16 87.76 88.5  88.38 85.78 76.95 89.06 87.93 88.5  10.
#  88.9  87.94 79.32 84.42 85.48 71.07 87.44 87.37]
# Final population ['|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|']
# Final population's fitness:  [91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52
#  91.52 91.52 91.52 91.52 91.52 91.52 91.52 91.52]
# Num of generations: 10
#
# The best architecture: |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|
# The highest test accuracy: 91.52
#
#
# ------------------------------------------
# Dataset: cifar100
# MRPS: 80
# Original population:  ['|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|skip_connect~1|none~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|none~0|+|none~0|skip_connect~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|none~1|none~2|'
#  '|skip_connect~0|+|none~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|avg_pool_3x3~1|none~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|skip_connect~1|none~2|'
#  '|none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|none~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|none~0|skip_connect~1|nor_conv_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|none~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|nor_conv_1x1~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|']
# Original population's fitness:  [68.25 66.16 67.11 61.47 67.18 63.41 67.33 63.46 68.19 62.5  10.27 47.06
#   1.   68.01 49.15 49.95 46.61 60.76 65.09  1.   69.01 69.91 67.34 61.51
#  68.2  58.25 64.41 68.19 63.99 60.96 67.34 65.33 63.95 41.03  1.   62.03
#  38.97 61.75 61.92 65.63 56.2  68.87 68.24 64.55 65.29 67.32 67.26 68.03
#  68.84 53.95 57.24 66.86 69.23 58.49 57.84 62.06 69.81 58.37 68.13 67.82
#  63.69 68.88 68.73 43.88 62.93 67.59 65.48 67.67 59.56 46.78 63.84 67.12
#  58.43 50.41 38.3  69.63 49.73 63.55 68.55 58.51]
# Final population ['|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|']
# Final population's fitness:  [73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51
#  73.51 73.51 73.51 73.51 73.51 73.51 73.51 73.51]
# Num of generations: 10
#
# The best architecture: |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|
# The highest test accuracy: 73.51
#
#
# ------------------------------------------
# Dataset: ImageNet16-120
# MRPS: 256
# Original population:  ['|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|none~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|none~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|'
#  '|skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|none~0|none~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|none~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|'
#  '|none~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|'
# ...
#  '|nor_conv_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|skip_connect~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|'
#  '|skip_connect~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|'
#  '|none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|none~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|'
#  '|none~0|+|none~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|none~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|none~1|none~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|none~1|+|none~0|none~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|none~1|nor_conv_1x1~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|none~2|'
#  '|avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|skip_connect~1|none~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|none~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|'
#  '|none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|'
#  '|none~0|+|none~0|none~1|+|none~0|skip_connect~1|nor_conv_3x3~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|none~2|'
#  '|none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|'
#  '|skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|none~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|none~1|nor_conv_1x1~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|none~2|'
#  '|none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|'
#  '|skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|'
#  '|skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|'
#  '|avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|'
#  '|nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|'
#  '|none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|skip_connect~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|'
#  '|none~0|+|avg_pool_3x3~0|none~1|+|none~0|skip_connect~1|none~2|'
#  '|nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|'
#  '|nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|'
#  '|skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|'
#  '|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|'
#  '|none~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|'
#  '|nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|skip_connect~1|skip_connect~2|']
# Original population's fitness:  [42.87 31.54 40.73 36.9  37.28 38.61 40.02 29.56 37.06 39.77 39.6  36.28
#  41.7  11.98 42.42 19.3  39.2  32.87 33.47 38.99 34.38 21.32 43.56 44.48
#  41.11 44.66 39.8  13.52 32.07 38.25 40.23 44.1  36.43 24.07 42.31 39.09
#  40.56 38.96 39.12 34.08 39.27 32.03 33.   23.7  39.2  39.96 38.63 38.35
#  36.34 39.72 35.71 32.06 38.33 43.23 40.88 28.34 29.48 38.58 43.4   0.83
#  39.87 36.94 27.99 37.12 38.37  0.83 42.87 32.01 42.15 27.87 38.67 15.31
#  36.25 42.38 38.59 38.87 45.47 41.34 39.82 39.3  28.51 38.38 43.42 43.43
#  38.61 43.96 33.51 30.65 43.07 27.01 39.37 31.87 39.27 27.85 16.32 43.3
#  39.45 42.5  27.03 36.74 37.74 35.83 17.39 22.19 32.86 42.8  44.05 40.37
#  41.7  15.93 15.95 39.02 13.68 45.3  39.4  36.03 43.43 30.73 45.93 37.06
#  41.48 36.56 30.23 16.18 45.21 41.92 28.43 15.5  33.48 41.2  41.09 43.53
#  44.44 39.11 40.82 32.53 28.31 42.98 16.12 43.77 37.88 40.85 33.1  40.54
#  39.85 43.02 37.72 36.82 36.42 39.65 30.73 43.03 37.52  0.83 45.17 38.67
#  15.59 42.6  39.13 32.85 29.56 38.1  22.73 39.36 43.   32.12 31.79 43.37
#  39.98 40.28 44.87 34.13 35.26 21.13 38.92 20.54 36.41 43.7  35.23 33.8
#  39.33 27.7  22.54 40.   40.72  0.83 24.33 44.28 32.37 36.23 17.37 22.27
#  15.78 45.4  40.07 41.39 26.51 40.   26.48 33.16 27.71 37.   37.18 15.3
#  45.46 38.67  0.83 16.93 32.37 45.9  31.97 34.68 36.19 23.32 31.66 44.04
#  25.94 28.6  41.49 40.58 11.99 33.65 43.52 41.91 23.85 34.13 21.02 15.87
#  32.36 36.7  15.26 38.99 33.65 38.41 41.23 20.21 33.63 39.68  0.83 37.37
#  39.75 33.82 38.27 28.32 39.28 38.39 42.43 45.31  0.83 32.03 33.68 44.71
#  41.12 40.41 15.9  38.5 ]
# Final population ['|nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|']
# Final population's fitness:  [47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31 47.31
#  47.31 47.31 47.31 47.31]
# Num of generations: 8
#
# The best architecture: |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|
# The highest test accuracy: 47.31
